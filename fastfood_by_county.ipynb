# %%
# Dependencies
import pandas as pd
import os
import glob

path = 'Resources'
fastfood_county = pd.DataFrame()

# get all csv files
csv_files = glob.glob(os.path.join(path, "*.csv"))


# Loop through files to store all csvs in a df
for f in csv_files:
    # read the file into dataframe
    file_load = pd.read_csv(f)
    
    # add column County and populate with filename - .csv
    # filename = f.strip("Resources/")
    # filename = filename.strip(".csv")
    # file_load["County"] = filename
    
    #transpose the data and remove the first column
    file_load = file_load.T
    file_load = file_load.iloc[1: , :]
    
    # add it to the main dataframe, ignoring the first 
    fastfood_county = fastfood_county.append(file_load, ignore_index=True)
        
    # print success
    print(f"loaded {f}")
# Out:
# loaded Resources/Brown.csv
# loaded Resources/Franklin.csv
# loaded Resources/Union.csv
# loaded Resources/Warren.csv
# loaded Resources/Moultrie.csv
# loaded Resources/Kane.csv
# loaded Resources/Crawford.csv
# loaded Resources/Jersey.csv
# loaded Resources/Iroquois.csv
# loaded Resources/Henry.csv
# loaded Resources/Clark.csv
# loaded Resources/Fayette.csv
# loaded Resources/Bond.csv
# loaded Resources/Vermilion.csv
# loaded Resources/Morgan.csv
# loaded Resources/Mason.csv
# loaded Resources/Kendall.csv
# loaded Resources/Saline.csv
# loaded Resources/Mercer.csv
# loaded Resources/LaSalle.csv
# loaded Resources/Coles.csv
# loaded Resources/Pope.csv
# loaded Resources/White.csv
# loaded Resources/Boone.csv
# loaded Resources/Marshall.csv
# loaded Resources/Scott.csv
# loaded Resources/Lee.csv
# loaded Resources/De_Witt.csv
# loaded Resources/Massac.csv
# loaded Resources/Edgar.csv
# loaded Resources/Logan.csv
# loaded Resources/Tazewell.csv
# loaded Resources/Macoupin.csv
# loaded Resources/Montgomery.csv
# loaded Resources/Pulaski.csv
# loaded Resources/Henderson.csv
# loaded Resources/Cook.csv
# loaded Resources/Knox.csv
# loaded Resources/Shelby.csv
# loaded Resources/Edwards.csv
# loaded Resources/Lake.csv
# loaded Resources/Sangamon.csv
# loaded Resources/Lawrence.csv
# loaded Resources/Richland.csv
# loaded Resources/Madison.csv
# loaded Resources/Wabash.csv
# loaded Resources/Winnebago.csv
# loaded Resources/Gallatin.csv
# loaded Resources/Ogle.csv
# loaded Resources/Hardin.csv
# loaded Resources/Effingham.csv
# loaded Resources/Calhoun.csv
# loaded Resources/Mchenry.csv
# loaded Resources/Livingston.csv
# loaded Resources/Bureau.csv
# loaded Resources/Dekalb.csv
# loaded Resources/Randolph.csv
# loaded Resources/Menard.csv
# loaded Resources/Monroe.csv
# loaded Resources/Stephenson.csv
# loaded Resources/DuPage.csv
# loaded Resources/Wayne.csv
# loaded Resources/Peoria.csv
# loaded Resources/Jo_Daviess.csv
# loaded Resources/Greene.csv
# loaded Resources/Marion.csv
# loaded Resources/Macon.csv
# loaded Resources/Will.csv
# loaded Resources/Champaign.csv
# loaded Resources/Cumberland.csv
# loaded Resources/Alexander.csv
# loaded Resources/Adams.csv
# loaded Resources/Perry.csv
# loaded Resources/Whiteside.csv
# loaded Resources/McLean.csv
# loaded Resources/Clinton.csv
# loaded Resources/Jackson.csv
# loaded Resources/Pike.csv
# loaded Resources/Williamson.csv
# loaded Resources/Douglas.csv
# loaded Resources/Ford.csv
# loaded Resources/Carroll.csv
# loaded Resources/Hancock.csv
# loaded Resources/Jasper.csv
# loaded Resources/Christian.csv
# loaded Resources/Piatt.csv
# loaded Resources/Jefferson.csv
# loaded Resources/McDonough.csv
# loaded Resources/Schuyler.csv
# loaded Resources/Grundy.csv
# loaded Resources/Cass.csv
# loaded Resources/Stark.csv
# loaded Resources/Hamilton.csv
# loaded Resources/Kankakee.csv
# loaded Resources/Rock_Island.csv
# loaded Resources/St_Clair.csv
# loaded Resources/Putnam.csv
# loaded Resources/Washington.csv
# loaded Resources/Clay.csv
# loaded Resources/Johnson.csv
# loaded Resources/Fulton.csv
# loaded Resources/Woodford.csv

# %%
fastfood_county
# Out:
#              0   1   2           3         4         5           6   7   8   \
# 0         Brown   2   4         100  0.290782   0.59312  103.973903   3   1
# 1      Franklin  23  23           0  0.574741  0.588356    2.368771  26  27
# 2         Union  11  16   45.454545  0.621785  0.934852   50.349773   9  10
# 3        Warren   7   8   14.285714  0.392531  0.462241   17.759123  12   9
# 4      Moultrie   3   3           0  0.202047  0.205494    1.705596   9  10
# ..          ...  ..  ..         ...       ...       ...         ...  ..  ..
# 97   Washington   7   9   28.571429  0.480307  0.633357   31.864884  11   8
# 98         Clay   8   9        12.5   0.58309  0.676133   15.956728   9  12
# 99      Johnson   6   4  -33.333333  0.466744  0.308618  -33.878559   6   7
# 100      Fulton  19  20    5.263158  0.514821  0.563111    9.379793  31  34
# 101    Woodford  17  18    5.882353  0.437648  0.462333    5.640308  26  21
#
#              9         10        11          12          13          14  \
# 0    -66.666667  0.436173   0.14828   -66.00435  629.814435  608.732214
# 1      3.846154  0.649708  0.690678    6.306032  629.814435  608.732214
# 2     11.111111  0.508733  0.584283   14.850521  629.814435  608.732214
# 3           -25   0.67291  0.520021  -22.720575  629.814435  608.732214
# 4     11.111111  0.606142  0.684978   13.006218  629.814435  608.732214
# ..          ...       ...       ...         ...         ...         ...
# 97   -27.272727  0.754769  0.562984  -25.409763  629.814435  608.732214
# 98    33.333333  0.655977   0.90151   37.430196  629.814435  608.732214
# 99    16.666667  0.466744  0.540082   15.712522  629.814435  608.732214
# 100    9.677419  0.839972  0.957288   13.966687  629.814435  608.732214
# 101  -19.230769  0.669344  0.539388  -19.415406  629.814435  608.732214
#
#              15          16
# 0    646.259252  697.649988
# 1    646.259252  697.649988
# 2    646.259252  697.649988
# 3    646.259252  697.649988
# 4    646.259252  697.649988
# ..          ...         ...
# 97   646.259252  697.649988
# 98   646.259252  697.649988
# 99   646.259252  697.649988
# 100  646.259252  697.649988
# 101  646.259252  697.649988
#
# [102 rows x 17 columns]
