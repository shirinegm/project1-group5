# %%
# Dependencies
import requests
import json
import pandas as pd

# Google developer API key
from api_key import api_key

# %%
base_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=fast%20food%20in%20Illinois&key={api_key}"

fast_food_data = requests.get(base_url).json()

# %%
# print a pretty json
print(json.dumps(fast_food_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDiJE-cGydQG0hJrQw7ulrwIUdJwvfeVWAQcgNPnXHZ4hobluolVxm27bb1HdnMH2G6FnMN-NOoKNAUUjCs3lx8rGBulu0Pjm4AYit2X-uT6w5zdH0GIOA-_WRJrTvZ3Qnyg67ZtQOhkNgiCDrJ_rWt3ZZme2hh7DSM4LUZdJ7mRMWbUFMOxjVzfdYU40MkLQcu4Jm14CEEOqDaYS_tZa-X5aQs0MmLuIjlJD9dmtScf8DOGvj-QK4wOt0V_oW6VBz-ZppTmeKIqN21QBeqleFApAM1iQ-celHCGDIUdnj7yd0w85goJEBcBRtaVG3tZUlXrOlidY6XL0BT1tcOr44n7wjXjsFgO8aJ0WRDZlcxwMF1-H3vK-gXz5PmOgtB3aNr7YDp1bf0SAafpYAOEaNEFg",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "formatted_address": "698 Illinois Rte 59, Naperville, IL 60540, United States",
#             "geometry": {
#                 "location": {
#                     "lat": 41.75941,
#                     "lng": -88.20528000000002
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.76071882989271,
#                         "lng": -88.20393432010728
# ...

# %%
# now pull the formatted address from each result

# first find out how many results

illinois_total = len(fast_food_data["results"])
illinois_total
# Out:
# 20

# %%
print(fast_food_data["results"][0]["formatted_address"])
# Out:
# 698 Illinois Rte 59, Naperville, IL 60540, United States
